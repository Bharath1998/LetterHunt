# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("gameData.csv")
df.head()
# Out:
#                         _id  level reason_end
# 0  6332b934d15932f04002bcda      1    TIME_UP
# 1  6333473fa342b01c8840bd25      1    SUCCESS
# 2  63334873a577df2ed6fde75d      1    SUCCESS
# 3  6333487da342b01c88410375      1    SUCCESS
# 4  6333488e09b0dac2f0947894      1    SUCCESS

# %%
count_ids=df["_id"].count()
count_ids
# Out:
# 65

# %%
X=["PLAYED", "SUCCESS"]
Y=[df["_id"].count(), df[df["reason_end"]=="SUCCESS"].count()["reason_end"]]
plt.bar(X,Y, color=[ 'blue', 'green',])
plt.xlabel("Level 1")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df[df["reason_end"]=="SUCCESS"].count()["reason_end"]
# Out:
# 54

# %%
df2=pd.read_csv("gameData3.csv")
df2
# Out:
#                          _id  correct_letters  enemies_killed  final_health  \
# 0   6340e37539bf83a8a187a23c                3               0           100
# 1   63422add7349da35faf6eb33                0               0             0
# 2   63422de09ad907cd667406a5                3               0            90
# 3   63423ad0b710d4e33ce9fc57                0               0            90
# 4   6344b7979d17bf045bfc2539                3               0           100
# 5   6344b7987d05e5bb5684480b                0               0           100
# 6   6344bb0cad13a1c2fba6d7d7                3               0           100
# 7   6344c28ceae925cc402f0348                2               0             0
# 8   6344c7c6a5493f5e25dae4bd                3               5            60
# 9   6344caee9d17bf045bfef3e7                3               1            50
# 10  6344cda8eae925cc4030b435                0               0            90
# ...

# %%
df_temp=df2[["correct_letters", "incorrect_letters", "level"]]
df_temp
# Out:
#     correct_letters  incorrect_letters  level
# 0                 3                  1      1
# 1                 0                  0      1
# 2                 3                  8      1
# 3                 0                  0      1
# 4                 3                  1      1
# 5                 0                  1      1
# 6                 3                  5      1
# 7                 2                  1      1
# 8                 3                  6      1
# 9                 3                  5      1
# 10                0                  1      1
# 11                3                  8      1
# 12                1                  4      1
# 13                0                  0      1
# 14                3                  7      1
# 15                0                  0      1
# 16                3                  0      1
# 17                0                  0      1
# 18                3                  7      1
# ...

# %%
df_count=df_temp.groupby(['level']).sum()
df_count
# Out:
#        correct_letters  incorrect_letters
# level
# 1                   42                 76

# %%
X=["Correct Letters", "Incorrect Letters"]
Y=[df_count["correct_letters"].squeeze(), df_count["incorrect_letters"].squeeze()]
Y
#Y=[np.array(df_count["correct_letters"]).reshape(-1,1), np.array(df_count["incorrect_letters"])]
#print(Y)
plt.bar(X,Y, color=[ 'blue', 'green',])
plt.xlabel("Level 1")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
temp_df=df2[["enemies_killed", "total_bullets", "level"]]
df3=temp_df.groupby(['level']).sum()
df3
# Out:
#        enemies_killed  total_bullets
# level
# 1                  23             48

# %%
X=["Enemies_killed", "Bullets fired"]
Y=[df3["enemies_killed"].squeeze(), df3["total_bullets"].squeeze()]
plt.bar(X,Y, color=[ 'red', 'blue'])
plt.xlabel("Level 1")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
new_df=pd.read_csv("gameData3T.csv")
Y=[group_new_df["orange"].squeeze(), group_new_df["yellow"].squeeze(), group_new_df["purple"].squeeze()]
X=["Orange Letters", "Yellow Letters", "Purple Letters"]
plt.bar(X,Y, color=[ 'Orange', 'Yellow',"Purple"])
plt.xlabel("Level 1")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
new_df["orange"]=new_df["correct_orange_letters"]+new_df["incorrect_orange_letters"]
new_df["purple"]=new_df["correct_purple_letters"]+new_df["incorrect_purple_letters"]
new_df["yellow"]=new_df["correct_yellow_letters"]+new_df["incorrect_yellow_letters"]
group_new_df=new_df.groupby(['level']).sum()
group_new_df=group_new_df[["orange","purple","yellow"]]
group_new_df
# Out:
#        orange  purple  yellow
# level
# 1          12      11      16

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
mid_df=pd.read_csv("gameData_v6.csv")
mid_df.head()
# Out:
#                         _id  correct_orange_letters  correct_purple_letters  \
# 0  6358dba730bdff1d4f905ec8                       2                       2
# 1  6358dc39c6ebe50c7834f1ba                       2                       1
# 2  6358dcadb446149f05836e8b                       2                       1
# 3  6358e0764604d65d2fa43571                       2                       1
# 4  6358e0a5c440047c81537340                       2                       2
#
#    correct_yellow_letters  enemies_killed  final_health  \
# 0                       3               3            10
# 1                       2               6            15
# 2                       2               0            15
# 3                       2               4            20
# 4                       3               5            60
#
#    incorrect_orange_letters  incorrect_purple_letters  \
# 0                         0                         2
# 1                         1                         2
# ...

# %%
mid_temp_df=mid_df[["level", "reason_end"]]
counts_mid=mid_temp_df.groupby(['level', "reason_end"])[['reason_end']]. count()

counts_mid
# Out:
#                   reason_end
# level reason_end
# 1     KILLED              14
#       SUCCESS             29
#       TIME_UP              2
# 2     KILLED               9
#       SUCCESS             47

# %%
counts_mid.plot(kind="bar")
